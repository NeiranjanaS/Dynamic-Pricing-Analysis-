# %%
import pandas as pd
from sqlalchemy import create_engine

# Read CSV
df = pd.read_csv(r"C:\Users\Hareesh\Desktop\Project 2\Data\hotel_bookings_cleaned.csv")

# Replace with your MySQL username, password and database name
engine = create_engine(
    "mysql+pymysql://root:root@localhost/travel"
)

# Create table and insert data
df.to_sql(
    "hotel_bookings_cleaned",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data imported successfully!")
# Out:
# Data imported successfully!
